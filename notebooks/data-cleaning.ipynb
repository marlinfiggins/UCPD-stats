# %% [markdown]
# # Data Cleaning
# Author: Marlin Figgins

# %%
# Importing neessary packages
import pandas as pd

# %%
# Loading Data
traffic_df = pd.read_csv("../data/traffic_df.csv")
field_interview_df = pd.read_csv("../data/field_interview_df.csv")

## For now, we'll restrict to traffic.
df = traffic_df
df.head()
# Out:
#                          Date/Time                         Location  \
# 0  No traffic stops for 06/01/2015  No traffic stops for 06/01/2015
# 1  No traffic stops for 06/02/2015  No traffic stops for 06/02/2015
# 2                 6/3/2015 9:26 AM              5600 S Stony Island
# 3                 6/4/2015 5:44 PM                     5900 S Ellis
# 4  No traffic stops for 06/05/2015  No traffic stops for 06/05/2015
#
#                               Race                           Gender  \
# 0  No traffic stops for 06/01/2015  No traffic stops for 06/01/2015
# 1  No traffic stops for 06/02/2015  No traffic stops for 06/02/2015
# 2                 African American                           Female
# 3                 African American                           Female
# 4  No traffic stops for 06/05/2015  No traffic stops for 06/05/2015
#
#                IDOT Classification  \
# 0  No traffic stops for 06/01/2015
# 1  No traffic stops for 06/02/2015
# 2              Traffic Sign/Signal
# 3                 Follow Too Close
# 4  No traffic stops for 06/05/2015
#
#                                      Reason for Stop  \
# 0                    No traffic stops for 06/01/2015
# 1                    No traffic stops for 06/02/2015
# 2  Stop Sign Violation, Failed to Yield to Pedest...
# 3  Following too closely to vehicle stopped for p...
# 4                    No traffic stops for 06/05/2015
#
#               Citations/Violations                      Disposition  \
# 0  No traffic stops for 06/01/2015  No traffic stops for 06/01/2015
# 1  No traffic stops for 06/02/2015  No traffic stops for 06/02/2015
# 2                              NaN                   Verbal Warning
# 3                              NaN                   Verbal Warning
# 4  No traffic stops for 06/05/2015  No traffic stops for 06/05/2015
#
#                             Search
# 0  No traffic stops for 06/01/2015
# 1  No traffic stops for 06/02/2015
# 2                               No
# 3                               No
# 4  No traffic stops for 06/05/2015

# %%
# We must drop rows containing "No [X] for [Y]" 
df = df[~df["Date/Time"].str.contains("traffic stops|field interviews|no|No")].reset_index(drop = True)
df.head()
# Out:
#             Date/Time              Location              Race  Gender  \
# 0    6/3/2015 9:26 AM   5600 S Stony Island  African American  Female
# 1    6/4/2015 5:44 PM          5900 S Ellis  African American  Female
# 2  6/27/2015 11:36 AM  6121 S Cottage Grove  African American    Male
# 3  7/11/2015 10:04 PM  5500 S Cottage Grove  African American    Male
# 4  7/11/2015 10:47 PM         5600 S Drexel  African American    Male
#
#         IDOT Classification  \
# 0       Traffic Sign/Signal
# 1          Follow Too Close
# 2            Lane Violation
# 3  Moving Violation - Other
# 4            Lane Violation
#
#                                      Reason for Stop Citations/Violations  \
# 0  Stop Sign Violation, Failed to Yield to Pedest...                  NaN
# 1  Following too closely to vehicle stopped for p...                  NaN
# 2  Subject was driving erratically and cut off an...                  NaN
# 3                   Failed to yield to CFD firetruck                  NaN
# 4                          Wrong way on one way road                  NaN
#
#       Disposition Search
# 0  Verbal Warning     No
# 1  Verbal Warning     No
# 2  Verbal Warning     No
# 3  Verbal Warning     No
# 4  Verbal Warning     No

# %% [markdown]
# # Standardizing and cleanig "Race" column

# %%
df['Race'].value_counts()
# Out:
# African American                          3276
# Caucasian                                  723
# Hispanic                                   217
# Asian                                      208
# ASIAN                                       18
# CAUCASIAN                                   17
# American Indian/Alaskan Native              10
# Native Hawaiian/Other Pacific Islander       4
# American Indian                              2
# Female                                       1
# African                                      1
# Male                                         1
# Name: Race, dtype: int64

# %% [markdown]
# Notice that there are issues with capitalization in the cases of "ASIAN", "CAUCASIAN", and issues with missing "/" and incomplete terms.
#
# We'll use the five racial categories used in the 2000 census as our standard for cleaning here:
# -  White American
# - Black or African American
# - Native American or Alaska Native:
# - Asian American
# - Native Hawaiian or Other Pacific Islander
#
# This means that the general issues in our data we're seeking to resolve are as follows:
#
# - If an entry contains "African", we'll classify as "Black / African American"
# - If an entry contains "American Indian", we'll classify as "American Indian/Alaskan Native"
# - Standard all entries to be in capital letters.

# %%
def standardize_race(race):
    """
    Takes in "Race" entry and returns in standardized format.
    """
    race = str(race).upper() # force upper case

    if "AMERICAN INDIAN" in race or "ALASKA" in race or "NATIVE AMERICAN" in race:
        return "NATIVE AMERICAN / ALASKAN NATIVE"

    if "AFRICAN" in race or "BLACK" in race:
        return "BLACK / AFRICAN AMERICAN"

    if "CAUCASIAN" in race or "WHITE" in race:
        return "WHITE AMERICAN / CAUCASIAN"

    if "HAWAIIAN" in race or "PACIFIC" in race:
        return "NATIVE HAWAIIAN / OTHER PACIFIC ISLANDER"

    if "HISPANIC" in race:
        return "HISPANIC"
    
    # If unclassified, return unchanged
    return race

# %%
df['Race'] = df["Race"].apply(standardize_race)
df['Race'].value_counts()
# Out:
# BLACK / AFRICAN AMERICAN                    3277
# WHITE AMERICAN / CAUCASIAN                   740
# ASIAN                                        226
# HISPANIC                                     217
# NATIVE AMERICAN / ALASKAN NATIVE              12
# NATIVE HAWAIIAN / OTHER PACIFIC ISLANDER       4
# MALE                                           1
# FEMALE                                         1
# Name: Race, dtype: int64

# %% [markdown]
# There's still the issue of the MALE and FEMALE entries but this appears to be due to a shifted row, but we'll drop them for ease since it is only two data points.

# %%
# REMOVE ROW IF GENDER IN RACE COLUMN
df[~df["Race"].isin(["MALE", "FEMALE"])]
# Out:
#                Date/Time              Location                      Race  \
# 0       6/3/2015 9:26 AM   5600 S Stony Island  BLACK / AFRICAN AMERICAN
# 1       6/4/2015 5:44 PM          5900 S Ellis  BLACK / AFRICAN AMERICAN
# 2     6/27/2015 11:36 AM  6121 S Cottage Grove  BLACK / AFRICAN AMERICAN
# 3     7/11/2015 10:04 PM  5500 S Cottage Grove  BLACK / AFRICAN AMERICAN
# 4     7/11/2015 10:47 PM         5600 S Drexel  BLACK / AFRICAN AMERICAN
# ...                  ...                   ...                       ...
# 4473  8/10/2020 12:44 PM     6200 S. Greenwood  BLACK / AFRICAN AMERICAN
# 4474   8/11/2020 9:06 PM    5300 S. University  BLACK / AFRICAN AMERICAN
# 4475  8/11/2020 11:05 PM   1412 E. 53rd Street  BLACK / AFRICAN AMERICAN
# 4476   8/12/2020 4:56 PM   1455 E. 53rd Street  BLACK / AFRICAN AMERICAN
# 4477   8/12/2020 9:41 PM    5400 S. Blackstone  BLACK / AFRICAN AMERICAN
#
#       Gender       IDOT Classification  \
# 0     Female       Traffic Sign/Signal
# 1     Female          Follow Too Close
# 2       Male            Lane Violation
# 3       Male  Moving Violation - Other
# 4       Male            Lane Violation
# ...      ...                       ...
# 4473    Male       Traffic sign/signal
# 4474    Male       Traffic sign/signal
# 4475    Male            Lane Violation
# 4476    Male            Lane Violation
# 4477  Female       Traffic sign/signal
#
#                                         Reason for Stop Citations/Violations  \
# 0     Stop Sign Violation, Failed to Yield to Pedest...                  NaN
# 1     Following too closely to vehicle stopped for p...                  NaN
# 2     Subject was driving erratically and cut off an...                  NaN
# 3                      Failed to yield to CFD firetruck                  NaN
# 4                             Wrong way on one way road                  NaN
# ...                                                 ...                  ...
# 4473  Disobey stop sign and failure to give right of...                  NaN
# 4474                                Disobeyed Stop Sign                  NaN
# 4475                        Wrong way on one way street  One Citation Issued
# 4476                        Wrong way on one way street                  NaN
# 4477  The motorist was observed disregarding a stop ...                  NaN
#
#           Disposition Search
# 0      Verbal Warning     No
# 1      Verbal Warning     No
# 2      Verbal Warning     No
# 3      Verbal Warning     No
# 4      Verbal Warning     No
# ...               ...    ...
# 4473   Verbal Warning     NO
# 4474   Verbal Warning     NO
# 4475  Citation Issued     NO
# 4476   Verbal Warning     NO
# 4477   Verbal Warning     NO
#
# [4476 rows x 9 columns]

# %% [markdown]
# # Separating Dates

# %%
df.head()
# Out:
#             Date/Time              Location                      Race  Gender  \
# 0    6/3/2015 9:26 AM   5600 S Stony Island  BLACK / AFRICAN AMERICAN  Female
# 1    6/4/2015 5:44 PM          5900 S Ellis  BLACK / AFRICAN AMERICAN  Female
# 2  6/27/2015 11:36 AM  6121 S Cottage Grove  BLACK / AFRICAN AMERICAN    Male
# 3  7/11/2015 10:04 PM  5500 S Cottage Grove  BLACK / AFRICAN AMERICAN    Male
# 4  7/11/2015 10:47 PM         5600 S Drexel  BLACK / AFRICAN AMERICAN    Male
#
#         IDOT Classification  \
# 0       Traffic Sign/Signal
# 1          Follow Too Close
# 2            Lane Violation
# 3  Moving Violation - Other
# 4            Lane Violation
#
#                                      Reason for Stop Citations/Violations  \
# 0  Stop Sign Violation, Failed to Yield to Pedest...                  NaN
# 1  Following too closely to vehicle stopped for p...                  NaN
# 2  Subject was driving erratically and cut off an...                  NaN
# 3                   Failed to yield to CFD firetruck                  NaN
# 4                          Wrong way on one way road                  NaN
#
#       Disposition Search
# 0  Verbal Warning     No
# 1  Verbal Warning     No
# 2  Verbal Warning     No
# 3  Verbal Warning     No
# 4  Verbal Warning     No

# %% [markdown]
# Since there are formatting inconsisenticies in Date/Time formatting in this dataset, we'll split Date and Time into seperate columns.

# %%
# Splitting Date Time
df['Date'] = df["Date/Time"].apply(lambda x: x.split()[0])
df['Time'] = df["Date/Time"].apply(lambda x: x.split(" ", 1)[1])

# %% [markdown]
# # Standardizing Gender column

# %%
df['Gender'] = df.Gender.str.upper()
df['Gender'].value_counts()
# Out:
# MALE                                  2860
# FEMALE                                1615
# FAILURE TO YIELD TO CROSSING GUARD       2
# Name: Gender, dtype: int64

# %%
## Script to implement

def clean_UCPD_data(in_df):
    """
    This cleans the raw data returned from scrape_UCPD_data.
    Removes shifted rows, parses dates, and standardizes Gender and Race.
    """
    # We must drop rows containing "No [X] for [Y]" 
    df = in_df[~in_df["Date/Time"].str.contains("traffic stops|field interviews|no|No")].reset_index(drop = True)

    # Standardizes gender capitalization
    df['Gender'] = df.Gender.str.upper()

    # Imposes 2000 census racial categoriees
    df['Race'] = df["Race"].apply(standardize_race)

    # REMOVE IF GENDER IN RACE COLUMN
    df[~df["Race"].isin(["MALE", "FEMALE"])]

    # Splits into Date, Time columns separately
    df['Date'] = df["Date/Time"].apply(lambda x: x.split(" ", 1)[0])
    df['Time'] = df["Date/Time"].apply(lambda x: x.split(" ", 1)[1])
    
    # Drop "Date/Time"
    df = df.drop(columns = ["Date/Time"])
    return df

# %%
import time

start = time.time()
field_interview_df_cleaned = clean_UCPD_data(field_interview_df)
field_interview_df_cleaned.to_csv("../data/field_interview_df_cleaned.csv", index = False)
end = time.time()
print(f"Cleaning data and exporting field_interview_df_cleaned.csv took {end - start} seconds.")
field_interview_df_cleaned.head()
# Out:
# Cleaning data and exporting field_interview_df_cleaned.csv took 0.01572108268737793 seconds.
#                Location                       Initiated By  \
# 0           1601 E 53rd  Citizen request for UCPD Response
# 1           1601 E 53rd  Citizen request for UCPD Response
# 2  5245 S Cottage Grove  Citizen request for UCPD Response
# 3     901 E 58th Street                               UCPD
# 4     901 E 58th Street                               UCPD
#
#                        Race  Gender  \
# 0  BLACK / AFRICAN AMERICAN  FEMALE
# 1  BLACK / AFRICAN AMERICAN    MALE
# 2  BLACK / AFRICAN AMERICAN    MALE
# 3  BLACK / AFRICAN AMERICAN    MALE
# 4  BLACK / AFRICAN AMERICAN  FEMALE
#
#                                      Reason for Stop  \
# 0  Citizen observed subject having a verbal argum...
# 1  Citizen observed subject having a verbal argum...
# 2  Complainant advised subject acted suspicious (...
# 3  Disturbance - Domestic Incident, prior inciden...
# 4  Disturbance - Domestic Incident, prior inciden...
#
#                        Disposition Search      Date      Time
# 0  Name checked; no further action     No  6/3/2015   1:40 PM
# 1  Name checked; no further action     No  6/3/2015   1:40 PM
# 2  Name checked; no further action     No  6/4/2015   8:21 PM
# 3  Name checked; no further action     No  6/4/2015  10:01 PM
# 4    Name checked; arrested by CPD     No  6/4/2015  10:01 PM

# %%
start = time.time()
traffic_df_cleaned = clean_UCPD_data(traffic_df)
traffic_df_cleaned.to_csv("../data/traffic_df_cleaned.csv", index = False)
end = time.time()
print(f"Cleaning data and exporting traffic_df_cleaned.csv took {end - start} seconds.")
traffic_df_cleaned.head()
# Out:
# Cleaning data and exporting traffic_df_cleaned.csv took 0.041895151138305664 seconds.
#                Location                      Race  Gender  \
# 0   5600 S Stony Island  BLACK / AFRICAN AMERICAN  FEMALE
# 1          5900 S Ellis  BLACK / AFRICAN AMERICAN  FEMALE
# 2  6121 S Cottage Grove  BLACK / AFRICAN AMERICAN    MALE
# 3  5500 S Cottage Grove  BLACK / AFRICAN AMERICAN    MALE
# 4         5600 S Drexel  BLACK / AFRICAN AMERICAN    MALE
#
#         IDOT Classification  \
# 0       Traffic Sign/Signal
# 1          Follow Too Close
# 2            Lane Violation
# 3  Moving Violation - Other
# 4            Lane Violation
#
#                                      Reason for Stop Citations/Violations  \
# 0  Stop Sign Violation, Failed to Yield to Pedest...                  NaN
# 1  Following too closely to vehicle stopped for p...                  NaN
# 2  Subject was driving erratically and cut off an...                  NaN
# 3                   Failed to yield to CFD firetruck                  NaN
# 4                          Wrong way on one way road                  NaN
#
#       Disposition Search       Date      Time
# 0  Verbal Warning     No   6/3/2015   9:26 AM
# 1  Verbal Warning     No   6/4/2015   5:44 PM
# 2  Verbal Warning     No  6/27/2015  11:36 AM
# 3  Verbal Warning     No  7/11/2015  10:04 PM
# 4  Verbal Warning     No  7/11/2015  10:47 PM
